# %% [markdown]
# <a href="https://colab.research.google.com/github/NithyaPKiran/Assignments/blob/main/Assignment_SLR_1_Delivery_Time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Question 1 - Delivery Time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from numpy.polynomial.polynomial import polyfit
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv("delivery_time.csv")
dataset.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
x = dataset["Sorting Time"]
y = dataset["Delivery Time"]

# %%
#Data Visualization
sns.distplot(y)
# Out:
# <ipython-input-5-b10463a0a530>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y)
# <Axes: xlabel='Delivery Time', ylabel='Density'>

# %%
sns.distplot(x)
# Out:
# <ipython-input-6-5ec1fbeebf40>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# <Axes: xlabel='Sorting Time', ylabel='Density'>

# %%
sns.regplot(x=dataset['Sorting Time'], y=dataset['Delivery Time'])
# Out:
# <Axes: xlabel='Sorting Time', ylabel='Delivery Time'>

# %%
#correlation
dataset.corr()
#82.57 % correlation
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %% [markdown]
# Regression Model

# %%
#Model 1 - No Transformation
model1 = sm.OLS(y, x).fit()
predictions = model1.predict(x)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.953
# Method:                 Least Squares   F-statistic:                              424.5
# Date:                Fri, 27 Oct 2023   Prob (F-statistic):                    6.12e-15
# Time:                        05:07:23   Log-Likelihood:                         -57.349
# No. Observations:                  21   AIC:                                      116.7
# Df Residuals:                      20   BIC:                                      117.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
## Log Transformation of Delivery time
y_log = np.log(dataset['Delivery Time'])
model2 = sm.OLS(y_log, x).fit()
predictions = model2.predict(x)
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.917
# Model:                            OLS   Adj. R-squared (uncentered):              0.912
# Method:                 Least Squares   F-statistic:                              219.7
# Date:                Fri, 27 Oct 2023   Prob (F-statistic):                    3.00e-12
# Time:                        05:07:23   Log-Likelihood:                         -25.284
# No. Observations:                  21   AIC:                                      52.57
# Df Residuals:                      20   BIC:                                      53.61
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#Model 3 Log transformation of Sorting time
x_log = np.log(dataset['Sorting Time'])
model3 = sm.OLS(y, x_log).fit()
predictions = model3.predict(x_log)
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.975
# Model:                            OLS   Adj. R-squared (uncentered):              0.974
# Method:                 Least Squares   F-statistic:                              791.0
# Date:                Fri, 27 Oct 2023   Prob (F-statistic):                    1.48e-17
# Time:                        05:07:23   Log-Likelihood:                         -51.035
# No. Observations:                  21   AIC:                                      104.1
# Df Residuals:                      20   BIC:                                      105.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#model 4 log Transformation of both delivery time and sorting time
model4 = sm.OLS(y_log,x_log).fit()
predicitons = model4.predict(x_log)
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.972
# Model:                            OLS   Adj. R-squared (uncentered):              0.970
# Method:                 Least Squares   F-statistic:                              688.7
# Date:                Fri, 27 Oct 2023   Prob (F-statistic):                    5.72e-17
# Time:                        05:07:23   Log-Likelihood:                         -13.899
# No. Observations:                  21   AIC:                                      29.80
# Df Residuals:                      20   BIC:                                      30.84
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# Model 5 - sqrt of Delivery time
y_sqrt = np.sqrt(dataset['Delivery Time'])
model5 = sm.OLS(y_sqrt, x).fit()
predictions = model5.predict(x)
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.930
# Model:                            OLS   Adj. R-squared (uncentered):              0.927
# Method:                 Least Squares   F-statistic:                              266.0
# Date:                Fri, 27 Oct 2023   Prob (F-statistic):                    5.09e-13
# Time:                        05:07:23   Log-Likelihood:                         -31.484
# No. Observations:                  21   AIC:                                      64.97
# Df Residuals:                      20   BIC:                                      66.01
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#Model 6 - sqrt of Sorting time
x_sqrt = np.sqrt(dataset['Sorting Time'])
model6 = sm.OLS(y, x_sqrt).fit()
predictions = model6.predict(x_sqrt)
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.975
# Model:                            OLS   Adj. R-squared (uncentered):              0.973
# Method:                 Least Squares   F-statistic:                              772.0
# Date:                Fri, 27 Oct 2023   Prob (F-statistic):                    1.88e-17
# Time:                        05:07:23   Log-Likelihood:                         -51.284
# No. Observations:                  21   AIC:                                      104.6
# Df Residuals:                      20   BIC:                                      105.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#Model 7 - sqrt transformation of both delivery and sorting time
model7 = sm.OLS(y_sqrt, x_sqrt).fit()
predictions = model7.predict(x_sqrt)
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              1542.
# Date:                Fri, 27 Oct 2023   Prob (F-statistic):                    2.10e-20
# Time:                        05:07:23   Log-Likelihood:                         -13.658
# No. Observations:                  21   AIC:                                      29.32
# Df Residuals:                      20   BIC:                                      30.36
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# Final Predictions
#
# Model 7 has the highest rsq and adjusted rsq values - 98.7%
#
# Hence Model 7 - sqrt transformation of both is the best fit model
